# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
        
tf.compat.v1.disable_v2_behavior()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From c:\users\shrey\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from keras.layers import Input, Reshape, Dropout, Dense, Flatten, BatchNormalization, Activation, ZeroPadding2D, Add, Multiply, GlobalAveragePooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model, load_model
from keras.optimizers import Adam
import keras.backend as K
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt

# %%
# Preview image Frame
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 4
SAVE_FREQ = 100

# Size vector to generate images from
NOISE_SIZE = 100

# Configuration
EPOCHS = 20000 # number of iterations
BATCH_SIZE = 8
GENERATE_RES = 3
IMAGE_SIZE = 128 # rows/cols
IMAGE_CHANNELS = 3

# %%
training_data = np.load('cubism_data.npy')

# %%
def build_discriminator(image_shape):
    Inputs = Input(image_shape)
    
    X = Conv2D(filters = 32, kernel_size=(3,3), strides=(2,2), padding='same')(Inputs)
    
    X_shortcut = X
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 64, kernel_size=(3,3), strides=(2,2), padding='same')(X)
    X = ZeroPadding2D(padding=((0,1),(0,1)))(X)
    X = BatchNormalization(momentum=0.8)(X)
    
    X_shortcut = Conv2D(filters = 64, kernel_size=(1,1), strides=(2,2))(X_shortcut)
    X_shortcut = ZeroPadding2D(padding=((0,1),(1,0)))(X_shortcut)
    X_shortcut = LeakyReLU(alpha=0.2)(X_shortcut)
    
    X = Add()([X, X_shortcut])
    
    X_shortcut = X
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 128, kernel_size=(3,3), strides=(2,2), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 256, kernel_size=(3,3), strides=(1,1), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    
    X_shortcut = Conv2D(filters = 256, kernel_size=(1,1), strides=(2,2))(X_shortcut)
    X_shortcut = LeakyReLU(alpha=0.2)(X_shortcut)
    
    X = Add()([X, X_shortcut])
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 512, kernel_size=(3,3), strides=(1,1), padding='valid')(X)
    X = BatchNormalization(momentum=0.8)(X)    
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Flatten()(X)
    
    X = Dense(1, activation = 'sigmoid')(X)
    
    return Model(inputs = Inputs, outputs=X)
    
    '''model = Sequential()
    model.add(Conv2D(32, kernel_size=3, strides=2,
    input_shape=image_shape, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding='same'))
    model.add(ZeroPadding2D(padding=((0, 1), (0, 1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))
    input_image = Input(shape=image_shape)
    validity = model(input_image)
    return Model(input_image, validity)'''

# %%
test = build_discriminator((128,128,3))
test.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_20 (InputLayer)           (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 64, 64, 32)   896         input_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_83 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_98[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 64, 64, 32)   0           leaky_re_lu_83[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 32, 32, 64)   18496       dropout_61[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 32, 32, 64)   2112        conv2d_98[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 33, 33, 64)   0           conv2d_99[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 33, 33, 64)   0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 33, 33, 64)   256         zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_84 (LeakyReLU)      (None, 33, 33, 64)   0           zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 33, 33, 64)   0           batch_normalization_57[0][0]
#                                                                  leaky_re_lu_84[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_85 (LeakyReLU)      (None, 33, 33, 64)   0           add_22[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 33, 33, 64)   0           leaky_re_lu_85[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 17, 17, 128)  73856       dropout_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 128)  512         conv2d_101[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_86 (LeakyReLU)      (None, 17, 17, 128)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 17, 17, 128)  0           leaky_re_lu_86[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 17, 17, 256)  295168      dropout_63[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 17, 17, 256)  16640       add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 256)  1024        conv2d_102[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_87 (LeakyReLU)      (None, 17, 17, 256)  0           conv2d_103[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 17, 17, 256)  0           batch_normalization_59[0][0]
#                                                                  leaky_re_lu_87[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_88 (LeakyReLU)      (None, 17, 17, 256)  0           add_23[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 17, 17, 256)  0           leaky_re_lu_88[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 15, 15, 512)  1180160     dropout_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 15, 15, 512)  2048        conv2d_104[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_89 (LeakyReLU)      (None, 15, 15, 512)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# dropout_65 (Dropout)            (None, 15, 15, 512)  0           leaky_re_lu_89[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 115200)       0           dropout_65[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1)            115201      flatten_10[0][0]
# ==================================================================================================
# Total params: 1,706,369
# Trainable params: 1,704,449
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
def build_generator(noise_size, channels):
    Inputs = Input((noise_size,))
    
    X = Dense(4*4*256, activation='relu')(Inputs)
    X = Reshape((4,4,256))(X)
    
    X_shortcut = X
    
    X = UpSampling2D()(X)
    X = Conv2D(filters = 256, kernel_size=(3,3), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    X = Activation('relu')(X)
    
    X_shortcut = GlobalAveragePooling2D()(X_shortcut)
    X_shortcut = Reshape((1,1,256))(X_shortcut)
    X_shortcut = Conv2D(filters = 64, kernel_size = (1,1))(X_shortcut)
    X_shortcut = Conv2D(filters = 256, kernel_size = (1,1))(X_shortcut)
    X_shortcut = Activation('relu')(X_shortcut)
    
    X = Multiply()([X, X_shortcut])
    
    X = UpSampling2D()(X)
    X = Conv2D(filters = 256, kernel_size=(3,3), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    X = Activation('relu')(X)
    
    X_shortcut = X
    
    for i in range(GENERATE_RES):
        X = UpSampling2D()(X)
        X = Conv2D(filters = 256, kernel_size=(3,3), padding='same')(X)
        X = BatchNormalization(momentum=0.8)(X)
        X = Activation('relu')(X)
    
    X_shortcut = GlobalAveragePooling2D()(X_shortcut)
    X_shortcut = Reshape((1,1,256))(X_shortcut)
    X_shortcut = Conv2D(filters = 64, kernel_size = (1,1))(X_shortcut)
    X_shortcut = Conv2D(filters = 256, kernel_size = (1,1))(X_shortcut)
    X_shortcut = Activation('relu')(X_shortcut)
    
    X = Multiply()([X, X_shortcut])
    
    X = Conv2D(channels, kernel_size=(3,3), padding='same')(X)
    X = Activation('tanh')(X)
    
    return Model(inputs = Inputs, outputs = X)
    '''model = Sequential()
    model.add(Dense(4 * 4 * 256, activation='relu',       input_dim=noise_size))
    model.add(Reshape((4, 4, 256)))
    model.add(UpSampling2D())
    model.add(Conv2D(256, kernel_size=3, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation('relu'))
    model.add(UpSampling2D())
    model.add(Conv2D(256, kernel_size=3, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation('relu'))
    for i in range(GENERATE_RES):
        model.add(UpSampling2D())
        model.add(Conv2D(256, kernel_size=3, padding='same'))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation('relu'))
    model.summary()
    model.add(Conv2D(channels, kernel_size=3, padding='same'))
    model.add(Activation('tanh'))
    inputs = Input(shape=(noise_size,))
    generated_image = model(inputs)
    
    return Model(inputs, generated_image)'''

# %%
test = build_generator(128, 3)

test.summary()
# Out:
# Model: "model_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_30 (InputLayer)           (None, 128)          0
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 4096)         528384      input_30[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 4, 4, 256)    0           dense_20[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_12 (Gl (None, 256)          0           reshape_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_41 (UpSampling2D) (None, 8, 8, 256)    0           reshape_20[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 1, 1, 256)    0           global_average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 8, 8, 256)    590080      up_sampling2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 1, 1, 64)     16448       reshape_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 8, 8, 256)    1024        conv2d_172[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 1, 1, 256)    16640       conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 8, 8, 256)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 1, 1, 256)    0           conv2d_174[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 8, 8, 256)    0           activation_47[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_42 (UpSampling2D) (None, 16, 16, 256)  0           multiply_11[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 16, 16, 256)  590080      up_sampling2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 16, 16, 256)  1024        conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 256)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_43 (UpSampling2D) (None, 32, 32, 256)  0           activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 32, 32, 256)  590080      up_sampling2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 32, 32, 256)  1024        conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 32, 32, 256)  0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_44 (UpSampling2D) (None, 64, 64, 256)  0           activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 64, 64, 256)  590080      up_sampling2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 64, 64, 256)  1024        conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 64, 64, 256)  0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 256)          0           activation_49[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_45 (UpSampling2D) (None, 128, 128, 256 0           activation_51[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 1, 1, 256)    0           global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 128, 128, 256 590080      up_sampling2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 1, 1, 64)     16448       reshape_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 128, 128, 256 1024        conv2d_178[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 1, 1, 256)    16640       conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 128, 128, 256 0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 1, 1, 256)    0           conv2d_180[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 128, 128, 256 0           activation_52[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 128, 128, 3)  6915        multiply_12[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 128, 128, 3)  0           conv2d_181[0][0]
# ==================================================================================================
# Total params: 3,556,995
# Trainable params: 3,554,435
# Non-trainable params: 2,560
# __________________________________________________________________________________________________

# %%
def save_images(cnt, noise):
    image_array = np.full((
        PREVIEW_MARGIN + (PREVIEW_ROWS * (IMAGE_SIZE + PREVIEW_MARGIN)),
        PREVIEW_MARGIN + (PREVIEW_COLS * (IMAGE_SIZE + PREVIEW_MARGIN)), 3),
        255, dtype=np.uint8)
    
    generated_images = generator.predict(noise)
    
    generated_images = 0.5 * generated_images + 0.5
    image_count = 0
    for row in range(PREVIEW_ROWS):
        for col in range(PREVIEW_COLS):
            r = row * (IMAGE_SIZE + PREVIEW_MARGIN) + PREVIEW_MARGIN
            c = col * (IMAGE_SIZE + PREVIEW_MARGIN) + PREVIEW_MARGIN
            image_array[r:r + IMAGE_SIZE, c:c +
                        IMAGE_SIZE] = generated_images[image_count] * 255
            image_count += 1
    output_path = 'output'
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    filename = os.path.join(output_path, f"trained-{cnt}.png")
    im = Image.fromarray(image_array)
    im.save(filename)

# %%
image_shape = (IMAGE_SIZE, IMAGE_SIZE, IMAGE_CHANNELS)

optimizer = Adam(lr=1.5e-4, beta_1=0.5)

discriminator = build_discriminator(image_shape)
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

generator = build_generator(NOISE_SIZE, IMAGE_CHANNELS)

random_input = Input(shape=(NOISE_SIZE,))

generated_image = generator(random_input)

discriminator.trainable = False

validity = discriminator(generated_image)

combined = Model(random_input, validity)
combined.compile(loss = 'binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
y_real = np.ones((BATCH_SIZE, 1))
y_fake = np.zeros((BATCH_SIZE, 1))

fixed_noise = np.random.normal(0,1, (PREVIEW_ROWS* PREVIEW_COLS, NOISE_SIZE))

cnt = 1

for epoch in range(EPOCHS):
    idx = np.random.randint(0, training_data.shape[0], BATCH_SIZE)
    x_real = training_data[idx]
    
    noise = np.random.normal(0,1, (BATCH_SIZE, NOISE_SIZE))
    x_fake = generator.predict(noise)
    
    discriminator_metric_real = discriminator.train_on_batch(x_real, y_real)
    
    discriminator_metric_generated = discriminator.train_on_batch(x_fake, y_fake)
    
    discriminator_metric = 0.5 * np.add(discriminator_metric_real, discriminator_metric_generated)
    
    generator_metric = combined.train_on_batch(noise, y_real)
    
    if(epoch % SAVE_FREQ == 0):
        save_images(cnt, fixed_noise)
        cnt += 1
        print(f"{epoch} epoch, Discriminator accuracy: {100*discriminator_metric[1]}, Generator accuracy: {100*generator_metric[1]}")
# Out:
# 0 epoch, Discriminator accuracy: 59.375, Generator accuracy: 0.0
# 100 epoch, Discriminator accuracy: 50.0, Generator accuracy: 37.5
# 200 epoch, Discriminator accuracy: 31.25, Generator accuracy: 12.5
# 300 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 400 epoch, Discriminator accuracy: 50.0, Generator accuracy: 37.5
# 500 epoch, Discriminator accuracy: 81.25, Generator accuracy: 25.0
# 600 epoch, Discriminator accuracy: 25.0, Generator accuracy: 37.5
# 700 epoch, Discriminator accuracy: 43.75, Generator accuracy: 0.0
# 800 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 900 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 1000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 25.0
# 1100 epoch, Discriminator accuracy: 50.0, Generator accuracy: 75.0
# 1200 epoch, Discriminator accuracy: 93.75, Generator accuracy: 25.0
# 1300 epoch, Discriminator accuracy: 37.5, Generator accuracy: 37.5
# 1400 epoch, Discriminator accuracy: 62.5, Generator accuracy: 25.0
# 1500 epoch, Discriminator accuracy: 56.25, Generator accuracy: 25.0
# 1600 epoch, Discriminator accuracy: 62.5, Generator accuracy: 12.5
# 1700 epoch, Discriminator accuracy: 75.0, Generator accuracy: 25.0
# 1800 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 1900 epoch, Discriminator accuracy: 75.0, Generator accuracy: 12.5
# 2000 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 2100 epoch, Discriminator accuracy: 62.5, Generator accuracy: 50.0
# 2200 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 2300 epoch, Discriminator accuracy: 43.75, Generator accuracy: 0.0
# 2400 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 2500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 2600 epoch, Discriminator accuracy: 25.0, Generator accuracy: 12.5
# 2700 epoch, Discriminator accuracy: 75.0, Generator accuracy: 12.5
# 2800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 25.0
# 2900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 3000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 3100 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 3200 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 3300 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 3400 epoch, Discriminator accuracy: 62.5, Generator accuracy: 25.0
# 3500 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 3600 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 3700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 3800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 3900 epoch, Discriminator accuracy: 37.5, Generator accuracy: 12.5
# 4000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 4100 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 4200 epoch, Discriminator accuracy: 43.75, Generator accuracy: 50.0
# 4300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 4400 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 4500 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 4600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 4700 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 4800 epoch, Discriminator accuracy: 50.0, Generator accuracy: 0.0
# 4900 epoch, Discriminator accuracy: 87.5, Generator accuracy: 25.0
# 5000 epoch, Discriminator accuracy: 50.0, Generator accuracy: 12.5
# 5100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 5200 epoch, Discriminator accuracy: 75.0, Generator accuracy: 12.5
# 5300 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 5400 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 5500 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 5600 epoch, Discriminator accuracy: 75.0, Generator accuracy: 12.5
# 5700 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 5800 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 5900 epoch, Discriminator accuracy: 75.0, Generator accuracy: 12.5
# 6000 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 6100 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 6200 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 6300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 6400 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 6500 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 6600 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 6700 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 6800 epoch, Discriminator accuracy: 37.5, Generator accuracy: 12.5
# 6900 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 7000 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 7100 epoch, Discriminator accuracy: 43.75, Generator accuracy: 0.0
# 7200 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 7300 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 7400 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 7500 epoch, Discriminator accuracy: 50.0, Generator accuracy: 25.0
# 7600 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 7700 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 7800 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 7900 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 8000 epoch, Discriminator accuracy: 62.5, Generator accuracy: 12.5
# 8100 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 8200 epoch, Discriminator accuracy: 75.0, Generator accuracy: 25.0
# 8300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 25.0
# 8400 epoch, Discriminator accuracy: 37.5, Generator accuracy: 37.5
# 8500 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 8600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 8700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 8800 epoch, Discriminator accuracy: 56.25, Generator accuracy: 12.5
# 8900 epoch, Discriminator accuracy: 68.75, Generator accuracy: 12.5
# 9000 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 9100 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 9200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 9300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 9400 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 9500 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 9600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 9700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 9800 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 9900 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 10000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 25.0
# 10100 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 10200 epoch, Discriminator accuracy: 75.0, Generator accuracy: 12.5
# 10300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 10400 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 10500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 10600 epoch, Discriminator accuracy: 50.0, Generator accuracy: 37.5
# 10700 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 10800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 10900 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 11000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11100 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 11200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11300 epoch, Discriminator accuracy: 50.0, Generator accuracy: 12.5
# 11400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11500 epoch, Discriminator accuracy: 62.5, Generator accuracy: 25.0
# 11600 epoch, Discriminator accuracy: 62.5, Generator accuracy: 12.5
# 11700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11800 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 11900 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 12000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 12100 epoch, Discriminator accuracy: 93.75, Generator accuracy: 37.5
# 12200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 12300 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 12400 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 12500 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 12600 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 12700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 12800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 12900 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 13000 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 13100 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 13200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 13300 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 13400 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 13500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 13600 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 13700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 13800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 13900 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 14000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 14100 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 14200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 14300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 14400 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 14500 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 14600 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 14700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 14800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 14900 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 15000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 15100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 15200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 15300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 15400 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 15500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 15600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 15700 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 15800 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 15900 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 16000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 16100 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 16200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 16300 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 16400 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 16500 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 16600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 16700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 16800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 16900 epoch, Discriminator accuracy: 56.25, Generator accuracy: 0.0
# 17000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 17100 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 17200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 17300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 17400 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 17500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 17600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 17700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 17800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 17900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 18100 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 18200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 18600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18700 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 18800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 18900 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 19000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 19100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 19200 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 19300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 19400 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 19500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 19600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 19700 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 19800 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 19900 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
