# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Restrict TensorFlow to only use the fourth GPU
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')

        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
        
tf.compat.v1.disable_v2_behavior()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From c:\users\shrey\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from keras.layers import Input, Reshape, Dropout, Dense, Flatten, BatchNormalization, Activation, ZeroPadding2D, Add, Multiply, GlobalAveragePooling2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D, Conv2DTranspose
from keras.models import Sequential, Model, load_model
from keras.optimizers import Adam
import keras.backend as K
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt

# %%
# Preview image Frame
PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 4
SAVE_FREQ = 100

# Size vector to generate images from
NOISE_SIZE = 100

# Configuration
EPOCHS = 20000 # number of iterations
BATCH_SIZE = 8
GENERATE_RES = 3
IMAGE_SIZE = 128 # rows/cols
IMAGE_CHANNELS = 3

# %%
training_data = np.load('analytical_cubism_data.npy')

# %%
def build_discriminator(image_shape):
    Inputs = Input(image_shape)
    
    X = Conv2D(filters = 32, kernel_size=(3,3), strides=(2,2), padding='same')(Inputs)
    
    #X_shortcut = X
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 64, kernel_size=(3,3), strides=(2,2), padding='same')(X)
    X = ZeroPadding2D(padding=((0,1),(0,1)))(X)
    X = BatchNormalization(momentum=0.8)(X)
    
#     X_shortcut = Conv2D(filters = 64, kernel_size=(1,1), strides=(2,2))(X_shortcut)
#     X_shortcut = ZeroPadding2D(padding=((0,1),(1,0)))(X_shortcut)
#     X_shortcut = LeakyReLU(alpha=0.2)(X_shortcut)
    
#     X = Add()([X, X_shortcut])
    
#     X_shortcut = X
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 128, kernel_size=(3,3), strides=(2,2), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 256, kernel_size=(3,3), strides=(1,1), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    
#     X_shortcut = Conv2D(filters = 256, kernel_size=(1,1), strides=(2,2))(X_shortcut)
#     X_shortcut = LeakyReLU(alpha=0.2)(X_shortcut)
    
#     X = Add()([X, X_shortcut])
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Conv2D(filters = 512, kernel_size=(3,3), strides=(1,1), padding='valid')(X)
    X = BatchNormalization(momentum=0.8)(X)    
    
    X = LeakyReLU(alpha=0.2)(X)
    X = Dropout(0.25)(X)
    X = Flatten()(X)
    
    X = Dense(1, activation = 'sigmoid')(X)
    
    return Model(inputs = Inputs, outputs=X)
    
    '''model = Sequential()
    model.add(Conv2D(32, kernel_size=3, strides=2,
    input_shape=image_shape, padding='same'))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding='same'))
    model.add(ZeroPadding2D(padding=((0, 1), (0, 1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))
    input_image = Input(shape=image_shape)
    validity = model(input_image)
    return Model(input_image, validity)'''

# %%
test = build_discriminator((128,128,3))
test.summary()
# Out:
# WARNING:tensorflow:From c:\users\shrey\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 33, 33, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 33, 33, 64)        256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 33, 33, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 33, 33, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 17, 17, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 17, 17, 128)       512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 17, 17, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 17, 17, 256)       1024
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 17, 17, 256)       0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 17, 17, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 15, 15, 512)       1180160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 15, 15, 512)       2048
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 15, 15, 512)       0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 15, 512)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 115200)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 115201
# =================================================================
# Total params: 1,687,617
# Trainable params: 1,685,697
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
def build_generator(noise_size, channels):
    Inputs = Input((noise_size,))
    
    X = Dense(4*4*256, activation='relu')(Inputs)
    X = Reshape((4,4,256))(X)
    
#    X_shortcut = X
    
    X = UpSampling2D()(X)
    X = Conv2D(filters = 256, kernel_size=(3,3), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    X = Activation('relu')(X)
    
#     X_shortcut = GlobalAveragePooling2D()(X_shortcut)
#     X_shortcut = Reshape((1,1,256))(X_shortcut)
#     X_shortcut = Conv2D(filters = 64, kernel_size = (1,1))(X_shortcut)
#     X_shortcut = Conv2D(filters = 256, kernel_size = (1,1))(X_shortcut)
#     X_shortcut = Activation('relu')(X_shortcut)

#     X = Multiply()([X, X_shortcut])
    
    X = UpSampling2D()(X)
    X = Conv2D(filters = 256, kernel_size=(3,3), padding='same')(X)
    X = BatchNormalization(momentum=0.8)(X)
    X = Activation('relu')(X)
    
    for i in range(GENERATE_RES):
        X = UpSampling2D()(X)
        if(i%2):
            X = Conv2D(filters = 256, kernel_size=(3,3), padding='same')(X)
        else:
            X = Conv2D(filters = 128, kernel_size=(3,3), padding='same')(X)
        X = BatchNormalization(momentum=0.8)(X)
        X = Activation('relu')(X)
    
    X = Conv2D(channels, kernel_size=(3,3), padding='same')(X)
    X = Activation('tanh')(X)
    
    return Model(inputs = Inputs, outputs = X)
    '''model = Sequential()
    model.add(Dense(4 * 4 * 256, activation='relu',       input_dim=noise_size))
    model.add(Reshape((4, 4, 256)))
    model.add(UpSampling2D())
    model.add(Conv2D(256, kernel_size=3, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation('relu'))
    model.add(UpSampling2D())
    model.add(Conv2D(256, kernel_size=3, padding='same'))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation('relu'))
    for i in range(GENERATE_RES):
        model.add(UpSampling2D())
        model.add(Conv2D(256, kernel_size=3, padding='same'))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation('relu'))
    model.summary()
    model.add(Conv2D(channels, kernel_size=3, padding='same'))
    model.add(Activation('tanh'))
    inputs = Input(shape=(noise_size,))
    generated_image = model(inputs)
    
    return Model(inputs, generated_image)'''

# %%
test = build_generator(128, 3)

test.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              528384
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 256)         0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 256)       0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 128)       295040
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_3 (Activation)    (None, 32, 32, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 64, 64, 256)       0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 128, 128, 256)     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 128, 128)     295040
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# activation_5 (Activation)    (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 128, 3)       3459
# _________________________________________________________________
# activation_6 (Activation)    (None, 128, 128, 3)       0
# =================================================================
# Total params: 2,601,347
# Trainable params: 2,599,299
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
def save_images(cnt, noise):
    image_array = np.full((
        PREVIEW_MARGIN + (PREVIEW_ROWS * (IMAGE_SIZE + PREVIEW_MARGIN)),
        PREVIEW_MARGIN + (PREVIEW_COLS * (IMAGE_SIZE + PREVIEW_MARGIN)), 3),
        255, dtype=np.uint8)
    
    generated_images = generator.predict(noise)
    
    generated_images = 0.5 * generated_images + 0.5
    image_count = 0
    for row in range(PREVIEW_ROWS):
        for col in range(PREVIEW_COLS):
            r = row * (IMAGE_SIZE + PREVIEW_MARGIN) + PREVIEW_MARGIN
            c = col * (IMAGE_SIZE + PREVIEW_MARGIN) + PREVIEW_MARGIN
            image_array[r:r + IMAGE_SIZE, c:c +
                        IMAGE_SIZE] = generated_images[image_count] * 255
            image_count += 1
    output_path = 'output'
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    filename = os.path.join(output_path, f"trained-{cnt}.png")
    im = Image.fromarray(image_array)
    im.save(filename)

# %%
image_shape = (IMAGE_SIZE, IMAGE_SIZE, IMAGE_CHANNELS)

optimizer = Adam(lr=1.5e-4, beta_1=0.5)

discriminator = build_discriminator(image_shape)
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

generator = build_generator(NOISE_SIZE, IMAGE_CHANNELS)

random_input = Input(shape=(NOISE_SIZE,))

generated_image = generator(random_input)

discriminator.trainable = False

validity = discriminator(generated_image)

combined = Model(random_input, validity)
combined.compile(loss = 'binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\users\shrey\appdata\local\programs\python\python37\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
y_real = np.ones((BATCH_SIZE, 1))
y_fake = np.zeros((BATCH_SIZE, 1))

fixed_noise = np.random.normal(0,1, (PREVIEW_ROWS* PREVIEW_COLS, NOISE_SIZE))

cnt = 1

for epoch in range(EPOCHS):
    idx = np.random.randint(0, training_data.shape[0], BATCH_SIZE)
    x_real = training_data[idx]
    
    noise = np.random.normal(0,1, (BATCH_SIZE, NOISE_SIZE))
    x_fake = generator.predict(noise)
    
    discriminator_metric_real = discriminator.train_on_batch(x_real, y_real)
    
    discriminator_metric_generated = discriminator.train_on_batch(x_fake, y_fake)
    
    discriminator_metric = 0.5 * np.add(discriminator_metric_real, discriminator_metric_generated)
    
    generator_metric = combined.train_on_batch(noise, y_real)
    
    if(epoch % SAVE_FREQ == 0):
        save_images(cnt, fixed_noise)
        cnt += 1
        print(f"{epoch} epoch, Discriminator accuracy: {100*discriminator_metric[1]}, Generator accuracy: {100*generator_metric[1]}")
# Out:
# c:\users\shrey\appdata\local\programs\python\python37\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# c:\users\shrey\appdata\local\programs\python\python37\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 0 epoch, Discriminator accuracy: 18.75, Generator accuracy: 100.0
# c:\users\shrey\appdata\local\programs\python\python37\lib\site-packages\keras\engine\training.py:297: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# 100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 300 epoch, Discriminator accuracy: 37.5, Generator accuracy: 0.0
# 400 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 600 epoch, Discriminator accuracy: 87.5, Generator accuracy: 25.0
# 700 epoch, Discriminator accuracy: 56.25, Generator accuracy: 0.0
# 800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 900 epoch, Discriminator accuracy: 37.5, Generator accuracy: 0.0
# 1000 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 1100 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 1200 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 1300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 1400 epoch, Discriminator accuracy: 50.0, Generator accuracy: 0.0
# 1500 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 1600 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 1700 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 1800 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 1900 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 2000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 2100 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 2200 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 2300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 2400 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 2500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 2600 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 2700 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 2800 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 2900 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 3000 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 3100 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 3200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 3300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 3400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 3500 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 3600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 3700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 3800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 3900 epoch, Discriminator accuracy: 50.0, Generator accuracy: 0.0
# 4000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 4100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 4200 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 4300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 4400 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 4500 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 4600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 4700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 4800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 4900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 5000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 5100 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 5200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 5300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 5400 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 5500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 5600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 5700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 5800 epoch, Discriminator accuracy: 56.25, Generator accuracy: 0.0
# 5900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 6000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 6100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 6200 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 6300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 6400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 6500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 6600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 6700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 6800 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 6900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7300 epoch, Discriminator accuracy: 56.25, Generator accuracy: 0.0
# 7400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 7700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 7900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 8000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 8100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 8200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 8300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 8400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 8500 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 8600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 8700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 8800 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 8900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 9000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 9100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 9200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 9300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 9400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 9500 epoch, Discriminator accuracy: 87.5, Generator accuracy: 25.0
# 9600 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 9700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 9800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 12.5
# 9900 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 10000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 10100 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 10200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 10300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 10400 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 10500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 10600 epoch, Discriminator accuracy: 62.5, Generator accuracy: 0.0
# 10700 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 10800 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 10900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11100 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 11200 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 11300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 11400 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 11500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 11700 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 11800 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 11900 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 12000 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 12100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 12200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 12300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 12400 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 12500 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 12600 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 12700 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 12800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 12900 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 13000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 13100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 13200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 13300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 13400 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 13500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 13600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 13700 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 13800 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 13900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 14000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 14100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 14200 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 14300 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 14400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 14500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 14600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 14700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 14800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 14900 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 15000 epoch, Discriminator accuracy: 68.75, Generator accuracy: 0.0
# 15100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 15200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 15300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 15400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 15500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 15600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 15700 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 15800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 25.0
# 15900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 16000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 16100 epoch, Discriminator accuracy: 75.0, Generator accuracy: 0.0
# 16200 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 16300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 16400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 16500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 16600 epoch, Discriminator accuracy: 50.0, Generator accuracy: 0.0
# 16700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 16800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 16900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 17000 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 17100 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 17200 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 17300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 17400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 17500 epoch, Discriminator accuracy: 93.75, Generator accuracy: 37.5
# 17600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 17700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 17800 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 17900 epoch, Discriminator accuracy: 87.5, Generator accuracy: 0.0
# 18000 epoch, Discriminator accuracy: 81.25, Generator accuracy: 12.5
# 18100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18200 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 18300 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 18400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18500 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18600 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18700 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18800 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 18900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 19000 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 19100 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 19200 epoch, Discriminator accuracy: 100.0, Generator accuracy: 12.5
# 19300 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 19400 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
# 19500 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 19600 epoch, Discriminator accuracy: 93.75, Generator accuracy: 0.0
# 19700 epoch, Discriminator accuracy: 81.25, Generator accuracy: 0.0
# 19800 epoch, Discriminator accuracy: 93.75, Generator accuracy: 12.5
# 19900 epoch, Discriminator accuracy: 100.0, Generator accuracy: 0.0
